# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#   sample  value
# 0     S1   12.5
# 1     S2   15.1
# 2     S3   13.2

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df
# Out:
#   sample  value
# 0     S1   12.5
# 1     S2   15.1
# 2     S3   13.2

# %%
print("Mean:", df["value"].mean())
# Out:
# Mean: 13.6

# %%
print("Standard Deviation:", df["value"].std())
# Out:
# Standard Deviation: 1.345362404707371

# %%
import matplotlib.pyplot as plt
df.plot(kind='bar', x='sample', y='value', title='Sample Values')
plt.show()
